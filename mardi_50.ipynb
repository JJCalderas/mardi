# %%
import pandas as pd
from glob import glob
from microtc.utils import load_model
from EvoMSA.base import EvoMSA
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
import numpy as np
from joblib import Parallel, delayed
import joblib as joblib
from timeit import default_timer as timer

import warnings
warnings.filterwarnings("ignore")

import winsound
winsound.Beep(3000, 900)


pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 1200

stacked_method = "sklearn.svm.LinearSVC"

# 9 Models Pre-Trained EvoMSA
pre_models_dict = {
    "davincis22": [load_model('pre_models/davincis22_Es.evomsa'), stacked_method],
    "detoxis21_aggressiveness" : [load_model('pre_models/detoxis21_aggressiveness_Es.evomsa'), stacked_method],
    "exist21" : [load_model('pre_models/exist21_Es.evomsa'), stacked_method],
    "haha21" : [load_model('pre_models/haha21_Es.evomsa'), stacked_method],
    "meoffendes21" : [load_model('pre_models/meoffendes21_Es.evomsa'), stacked_method],
    "mexa3t18_aggress" : [load_model('pre_models/mexa3t18_aggress_Es.evomsa'), stacked_method],
    "misogyny_centrogeo" : [load_model('pre_models/misogyny_centrogeo_Es.evomsa'), stacked_method],
    "metwo22" : [load_model('pre_models/metwo22_Es.evomsa'), stacked_method],
    "haha18" : [load_model('pre_models/haha18_Es.evomsa'), stacked_method]
}  

print(len(pre_models_dict.keys()), pre_models_dict.keys())

df_samples = pd.read_csv('premodels_combinations_50.csv')
df_samples.rename(columns = {df_samples.columns[0]:'Idx'}, inplace = True)
df_samples.drop('Idx', inplace=True, axis=1)
#df_samples.fillna("", inplace=True)
df_samples
# Out:
# 9 dict_keys(['davincis22', 'detoxis21_aggressiveness', 'exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22', 'haha18'])
#                            0                         1                   2  \
# 0   detoxis21_aggressiveness                    haha21    mexa3t18_aggress
# 1                 davincis22              meoffendes21    mexa3t18_aggress
# 2   detoxis21_aggressiveness                    haha21        meoffendes21
# 3   detoxis21_aggressiveness                   exist21              haha21
# 4                 davincis22  detoxis21_aggressiveness             exist21
# 5                 davincis22  detoxis21_aggressiveness             exist21
# 6                 davincis22                   exist21              haha21
# 7                 davincis22              meoffendes21    mexa3t18_aggress
# 8                 davincis22                   exist21              haha21
# 9                 davincis22                   exist21        meoffendes21
# 10  detoxis21_aggressiveness                    haha21    mexa3t18_aggress
# 11                davincis22  detoxis21_aggressiveness        meoffendes21
# 12                   exist21                    haha21    mexa3t18_aggress
# 13              meoffendes21                   metwo22              haha18
# 14                davincis22                   exist21    mexa3t18_aggress
# 15                davincis22  detoxis21_aggressiveness             exist21
# 16                    haha21          mexa3t18_aggress  misogyny_centrogeo
# 17                davincis22                   exist21             metwo22
# 18  detoxis21_aggressiveness                    haha21        meoffendes21
# 19  detoxis21_aggressiveness              meoffendes21    mexa3t18_aggress
# 20                davincis22                    haha21  misogyny_centrogeo
# 21                davincis22  detoxis21_aggressiveness              haha21
# 22                davincis22  detoxis21_aggressiveness             exist21
# 23  detoxis21_aggressiveness                   exist21  misogyny_centrogeo
# 24                davincis22                   exist21        meoffendes21
# 25          mexa3t18_aggress        misogyny_centrogeo              haha18
# 26                davincis22  detoxis21_aggressiveness             exist21
# 27                davincis22  detoxis21_aggressiveness    mexa3t18_aggress
# 28                davincis22  detoxis21_aggressiveness             exist21
# 29  detoxis21_aggressiveness                    haha21        meoffendes21
# 30          mexa3t18_aggress                   metwo22              haha18
# 31                davincis22  detoxis21_aggressiveness             exist21
# 32  detoxis21_aggressiveness                   exist21    mexa3t18_aggress
# 33                   exist21                    haha21        meoffendes21
# 34                davincis22              meoffendes21    mexa3t18_aggress
# 35                davincis22  detoxis21_aggressiveness              haha21
# 36                   exist21          mexa3t18_aggress             metwo22
# 37                   exist21                    haha21        meoffendes21
# 38                davincis22                   exist21              haha21
# 39                davincis22  detoxis21_aggressiveness              haha21
# 40                   exist21                   metwo22              haha18
# 41                davincis22                   exist21        meoffendes21
# 42                   exist21          mexa3t18_aggress             metwo22
# 43                davincis22  detoxis21_aggressiveness              haha21
# 44                   exist21                    haha21    mexa3t18_aggress
# 45                   exist21          mexa3t18_aggress              haha18
# 46  detoxis21_aggressiveness                   exist21        meoffendes21
# 47  detoxis21_aggressiveness        misogyny_centrogeo             metwo22
# 48                davincis22  detoxis21_aggressiveness        meoffendes21
# 49  detoxis21_aggressiveness                   exist21              haha21
# 50                       NaN                       NaN                 NaN
#
#                      3                   4                   5  \
# 0              metwo22              haha18                 NaN
# 1               haha18                 NaN                 NaN
# 2   misogyny_centrogeo                 NaN                 NaN
# 3              metwo22                 NaN                 NaN
# 4               haha21        meoffendes21    mexa3t18_aggress
# 5               haha21        meoffendes21                 NaN
# 6     mexa3t18_aggress             metwo22              haha18
# 7   misogyny_centrogeo              haha18                 NaN
# 8     mexa3t18_aggress  misogyny_centrogeo              haha18
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11    mexa3t18_aggress  misogyny_centrogeo             metwo22
# 12  misogyny_centrogeo                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14  misogyny_centrogeo             metwo22                 NaN
# 15  misogyny_centrogeo             metwo22                 NaN
# 16             metwo22                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18              haha18                 NaN                 NaN
# 19  misogyny_centrogeo              haha18                 NaN
# 20             metwo22                 NaN                 NaN
# 21    mexa3t18_aggress             metwo22              haha18
# 22    mexa3t18_aggress  misogyny_centrogeo              haha18
# 23             metwo22              haha18                 NaN
# 24  misogyny_centrogeo             metwo22              haha18
# 25                 NaN                 NaN                 NaN
# 26    mexa3t18_aggress                 NaN                 NaN
# 27  misogyny_centrogeo                 NaN                 NaN
# 28              haha21                 NaN                 NaN
# 29                 NaN                 NaN                 NaN
# 30                 NaN                 NaN                 NaN
# 31              haha21        meoffendes21    mexa3t18_aggress
# 32  misogyny_centrogeo              haha18                 NaN
# 33    mexa3t18_aggress             metwo22              haha18
# 34             metwo22              haha18                 NaN
# 35             metwo22              haha18                 NaN
# 36                 NaN                 NaN                 NaN
# 37    mexa3t18_aggress                 NaN                 NaN
# 38        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 39        meoffendes21             metwo22              haha18
# 40                 NaN                 NaN                 NaN
# 41  misogyny_centrogeo                 NaN                 NaN
# 42              haha18                 NaN                 NaN
# 43        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 44             metwo22                 NaN                 NaN
# 45                 NaN                 NaN                 NaN
# 46  misogyny_centrogeo                 NaN                 NaN
# 47              haha18                 NaN                 NaN
# 48             metwo22              haha18                 NaN
# 49        meoffendes21                 NaN                 NaN
# 50                 NaN                 NaN                 NaN
#
#                      6
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4              metwo22
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31  misogyny_centrogeo
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38             metwo22
# 39                 NaN
# 40                 NaN
# 41                 NaN
# 42                 NaN
# 43             metwo22
# 44                 NaN
# 45                 NaN
# 46                 NaN
# 47                 NaN
# 48                 NaN
# 49                 NaN
# 50                 NaN

# %%
def process(fn):

    train_df = pd.read_json(fn, lines=True)
    test_df = pd.read_json(fn.replace("_train", "_test"), lines=True)

    # recortarlos
    #train_df = train_df.loc[0:89, ['text', 'klass']]
    #test_df = test_df.loc[0:16, ['text', 'klass']]

    X_train, y_train = train_df['text'], train_df['klass']
    X_test,  y_test  = test_df['text'],  test_df['klass']
       
    ds_n = fn.replace("dataset_es\\",'').replace("dataset_es/",'').replace('_Es_train.json','')

    print(ds_n, train_df.shape, test_df.shape)

    X_F, y_F = train_df['text'], train_df['klass']  # X, y  Folds
   
    for i, sample in df_samples.iterrows():   ### [:3] [3:4]
        try:
            # remueve el pre-model (de la combinacion) si coincide con el dataset en evaluacion
            sample_avoid = sample.dropna().values[sample.dropna().values != ds_n]
            # toma los objetos de los pre-modelos
            pre_models = [pre_models_dict[key] for key in sample_avoid]  
           
            ### train & test ###
            evo = EvoMSA(TR=True, B4MSA=True, lang='es', Emo=True, HA=True, stacked_method=stacked_method, models = pre_models)                
            evo.fit(X_train, y_train)                
            pred = evo.predict(X_test)
            recall_score = metrics.recall_score(y_test, pred, average="macro")
            f1_score = metrics.f1_score(y_test, pred, average="macro")

            winsound.Beep(4500, 300)
           
            ### K-Fold / train ###
            scores_kfold = []
            skf = StratifiedKFold(n_splits=5)
            for train_index, test_index in skf.split(X_F, y_F):
                X_train_F, X_test_F = X_F[train_index], X_F[test_index]
                y_train_F, y_test_F = y_F[train_index], y_F[test_index]    

                evo = EvoMSA(TR=True, B4MSA=True, lang='es', Emo=True, HA=True, stacked_method=stacked_method, models = pre_models)                
                evo.fit(X_train_F, y_train_F)                
                pred = evo.predict(X_test_F)
                recall_score = metrics.recall_score(y_test_F, pred, average="macro")
                f1_score_F = metrics.f1_score(y_test_F, pred, average="macro")

                scores_kfold.append(f1_score_F)

                winsound.Beep(4500, 300)
               
               
            #scores = ', '.join([str(s) for s in scores_kfold])                
            _ = [ds_n, i, train_df.shape, test_df.shape, f1_score, recall_score, 
                 sample_avoid.tolist(),
                 i, train_df.shape, np.mean(scores_kfold, axis=0), np.std(scores_kfold, axis=0), np.min(scores_kfold), np.max(scores_kfold), scores_kfold]
                     
            with open('debug_build.txt', 'a', encoding='utf-8') as the_file:
                txt = ', '.join([str(r) for r in _]) 
                the_file.write(txt)
                the_file.write('\n')
            print(_)
           
            results.append(_)

        except Exception as ex:
            winsound.Beep(500, 100)
            winsound.Beep(500, 100)
            winsound.Beep(500, 100)
            winsound.Beep(500, 100)
            print('>>', ex)
            with open('debug_build.txt', 'a', encoding='utf-8') as the_file:
                the_file.write('\n')
                the_file.write('=======================================================\n')
                the_file.write('Exception: ' + ds_n + ' > ' + str(i) + ' > ' + '\n')
                the_file.write(ex + '\n')
        finally:
            winsound.Beep(3000, 900)

    return results

# %%
if False:
    results = []
    fnames = glob("dataset_es/meoff*_train.json") ## todos los train datasets
    fnames.sort()
    for fn in fnames:
        print(fn)
        process(fn)

# %%
fnames = glob("dataset_es/m*_train.json") ## todos los train datasets
fnames.sort()
results = []
parallel_pool = Parallel(n_jobs=7)
delayed_funcs = [delayed(process)(fn) for fn in fnames]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 fnames = glob("dataset_es/me*_train.json") ## todos los train datasets
#       2 fnames.sort()
#       3 results = []
#
# NameError: name 'glob' is not defined

# %%
start = timer()
results = parallel_pool(delayed_funcs)
end = timer()
print(end - start)

winsound.Beep(500, 900)
# Out:
# 924.2143143999999

# %%
clean_results = []
for r in results:
    for a in r:
        clean_results.append(a)

results_df = pd.DataFrame(data=clean_results, columns=['dataset', 'combina_1', 'train.shape', 'test.shape', 'f1', 'recall', 
                                                       'combinations', 'combina_2', 'train.shape', 'mean', 'std', 'min', 'max', 'scores_kfold' ])
results_df.to_csv('results_full_03.csv')
#results_df

print('--- done ---')
# Out:
# --- done ---
